# %%
# %pylab inline 
from math import factorial
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def p(n):
    result = 1.0
    for i in range(n):
        result *= (365.0 - i)/365
    return 1 - result
print(p(100))
# Out:
# 0.9999996927510721

# %%
# def p(n):
#     return 1 - factorial(365)/factorial(365-n)/pow(365, n)
# def p_appro(n):
#     return 1 - exp((365 - n + 1/2)*log(365/(365-n))-n)
x = np.arange(1, 365, 1)

y = [p(i) for i in x]

figure()

axhline(0.5)
# ylim(0.999, 1)
plot(x, y)
grid()
show()

# %%
figure()

axvline(100)
ylim(0.999999, 1)
xlim(98, 101)
plot(x, y)
grid()
show()

# %%
figure()

axhline(0.5)
ylim(0.49, 0.51)
xlim(22, 24)
plot(x, y)
grid()
show()
